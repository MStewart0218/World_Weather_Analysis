# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da1d49f96fef98b8dd04698790ab94dc

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping..." + city)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | takoradi
# Processing Record 3 of Set 1 | kruisfontein
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | yuncheng
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | tiarei
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | tarazona
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | honningsvag
# Processing Record 16 of Set 1 | vila
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | meulaboh
# Processing Record 19 of Set 1 | qazvin
# Processing Record 20 of Set 1 | itarema
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | shu
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | kuche
# City not found. Skipping...kuche
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | amga
# Processing Record 28 of Set 1 | tilichiki
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | fergus falls
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | hohhot
# Processing Record 36 of Set 1 | broome
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | pakxan
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | dien bien
# City not found. Skipping...dien bien
# Processing Record 43 of Set 1 | warqla
# City not found. Skipping...warqla
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...umzimvubu
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | tanout
# Processing Record 48 of Set 1 | uarini
# Processing Record 49 of Set 1 | kailua
# Processing Record 50 of Set 1 | abeche
# Processing Record 1 of Set 2 | miles city
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | vaitupu
# City not found. Skipping...vaitupu
# Processing Record 5 of Set 2 | yarada
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | cape canaveral
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...sentyabrskiy
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...amderma
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | one hundred mile house
# City not found. Skipping...one hundred mile house
# Processing Record 16 of Set 2 | riverton
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | abha
# Processing Record 19 of Set 2 | erzin
# Processing Record 20 of Set 2 | north bend
# Processing Record 21 of Set 2 | yar-sale
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | rocha
# Processing Record 24 of Set 2 | tallahassee
# Processing Record 25 of Set 2 | vathi
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...illoqqortoormiut
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | carahue
# Processing Record 30 of Set 2 | gat
# Processing Record 31 of Set 2 | minna
# Processing Record 32 of Set 2 | duzce
# Processing Record 33 of Set 2 | high level
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | sechura
# Processing Record 36 of Set 2 | tumannyy
# City not found. Skipping...tumannyy
# Processing Record 37 of Set 2 | yeniseysk
# Processing Record 38 of Set 2 | terre-de-bas
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | saint anthony
# Processing Record 42 of Set 2 | apodi
# Processing Record 43 of Set 2 | taber
# Processing Record 44 of Set 2 | asau
# Processing Record 45 of Set 2 | salalah
# Processing Record 46 of Set 2 | viedma
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | rawson
# Processing Record 50 of Set 2 | atambua
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | gurskoye
# City not found. Skipping...gurskoye
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | ludvika
# Processing Record 5 of Set 3 | poum
# Processing Record 6 of Set 3 | ilulissat
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | venta
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...lolua
# Processing Record 12 of Set 3 | dekoa
# City not found. Skipping...dekoa
# Processing Record 13 of Set 3 | abu dhabi
# Processing Record 14 of Set 3 | turinsk
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | saint george
# Processing Record 18 of Set 3 | riyadh
# Processing Record 19 of Set 3 | ler
# Processing Record 20 of Set 3 | martapura
# Processing Record 21 of Set 3 | sambava
# Processing Record 22 of Set 3 | anadyr
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...taolanaro
# Processing Record 24 of Set 3 | edd
# Processing Record 25 of Set 3 | mao
# Processing Record 26 of Set 3 | mergui
# City not found. Skipping...mergui
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | faya
# Processing Record 29 of Set 3 | ekhabi
# Processing Record 30 of Set 3 | bergerac
# Processing Record 31 of Set 3 | ryotsu
# Processing Record 32 of Set 3 | gao
# Processing Record 33 of Set 3 | nioro
# Processing Record 34 of Set 3 | erenhot
# Processing Record 35 of Set 3 | inongo
# Processing Record 36 of Set 3 | haines junction
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | touros
# Processing Record 39 of Set 3 | bay roberts
# Processing Record 40 of Set 3 | greencastle
# Processing Record 41 of Set 3 | ukiah
# Processing Record 42 of Set 3 | jacareacanga
# Processing Record 43 of Set 3 | tsihombe
# City not found. Skipping...tsihombe
# Processing Record 44 of Set 3 | tuggurt
# City not found. Skipping...tuggurt
# Processing Record 45 of Set 3 | fandriana
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | libourne
# Processing Record 48 of Set 3 | samusu
# City not found. Skipping...samusu
# Processing Record 49 of Set 3 | enid
# Processing Record 50 of Set 3 | tura
# Processing Record 1 of Set 4 | badiraguato
# Processing Record 2 of Set 4 | palmer
# Processing Record 3 of Set 4 | upernavik
# Processing Record 4 of Set 4 | dalhousie
# Processing Record 5 of Set 4 | kegayli
# City not found. Skipping...kegayli
# Processing Record 6 of Set 4 | parker
# Processing Record 7 of Set 4 | khash
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | attawapiskat
# City not found. Skipping...attawapiskat
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...nizhneyansk
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | pecos
# Processing Record 15 of Set 4 | margate
# Processing Record 16 of Set 4 | sri aman
# Processing Record 17 of Set 4 | mackay
# Processing Record 18 of Set 4 | sierra vista
# Processing Record 19 of Set 4 | vila velha
# Processing Record 20 of Set 4 | hihifo
# City not found. Skipping...hihifo
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | bemidji
# Processing Record 24 of Set 4 | suntar
# Processing Record 25 of Set 4 | sabancuy
# Processing Record 26 of Set 4 | bandarbeyla
# Processing Record 27 of Set 4 | lesozavodsk
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | ribeira grande
# Processing Record 30 of Set 4 | kopavogur
# Processing Record 31 of Set 4 | clyde river
# Processing Record 32 of Set 4 | fortuna
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | half moon bay
# Processing Record 36 of Set 4 | togur
# Processing Record 37 of Set 4 | bulolo
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | hami
# Processing Record 40 of Set 4 | romans-sur-isere
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | sola
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | karratha
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | marathon
# Processing Record 47 of Set 4 | tsumeb
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...belushya guba
# Processing Record 49 of Set 4 | maragogi
# Processing Record 50 of Set 4 | qeshm
# Processing Record 1 of Set 5 | naze
# Processing Record 2 of Set 5 | taoudenni
# Processing Record 3 of Set 5 | zeya
# Processing Record 4 of Set 5 | bima
# Processing Record 5 of Set 5 | tourlaville
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | roebourne
# Processing Record 8 of Set 5 | malanje
# Processing Record 9 of Set 5 | batagay
# Processing Record 10 of Set 5 | te anau
# Processing Record 11 of Set 5 | grand river south east
# City not found. Skipping...grand river south east
# Processing Record 12 of Set 5 | anderson
# Processing Record 13 of Set 5 | moose factory
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | san patricio
# Processing Record 17 of Set 5 | ongandjera
# Processing Record 18 of Set 5 | port hawkesbury
# Processing Record 19 of Set 5 | port hedland
# Processing Record 20 of Set 5 | price
# Processing Record 21 of Set 5 | redlands
# Processing Record 22 of Set 5 | turayf
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | pevek
# Processing Record 25 of Set 5 | isetskoye
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | little chute
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | nouakchott
# Processing Record 30 of Set 5 | onalaska
# Processing Record 31 of Set 5 | port alfred
# Processing Record 32 of Set 5 | hithadhoo
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | nkhata bay
# Processing Record 35 of Set 5 | namibe
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | beloha
# Processing Record 38 of Set 5 | guane
# Processing Record 39 of Set 5 | san luis
# Processing Record 40 of Set 5 | fort nelson
# Processing Record 41 of Set 5 | husainabad
# Processing Record 42 of Set 5 | deniliquin
# Processing Record 43 of Set 5 | jieshi
# Processing Record 44 of Set 5 | kununurra
# Processing Record 45 of Set 5 | kamalpur
# Processing Record 46 of Set 5 | semenivka
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | severo-kurilsk
# Processing Record 49 of Set 5 | nerchinskiy zavod
# Processing Record 50 of Set 5 | mar del plata
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | skibbereen
# Processing Record 3 of Set 6 | scarborough
# Processing Record 4 of Set 6 | samarai
# Processing Record 5 of Set 6 | khandyga
# Processing Record 6 of Set 6 | walvis bay
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | gushikawa
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | kita
# Processing Record 11 of Set 6 | pachino
# Processing Record 12 of Set 6 | butembo
# Processing Record 13 of Set 6 | chipoka
# Processing Record 14 of Set 6 | winnemucca
# Processing Record 15 of Set 6 | sandwick
# Processing Record 16 of Set 6 | byron bay
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | port-gentil
# Processing Record 19 of Set 6 | guerrero negro
# Processing Record 20 of Set 6 | srednekolymsk
# Processing Record 21 of Set 6 | tazovskiy
# Processing Record 22 of Set 6 | karaul
# City not found. Skipping...karaul
# Processing Record 23 of Set 6 | ry
# City not found. Skipping...ry
# Processing Record 24 of Set 6 | tabiauea
# City not found. Skipping...tabiauea
# Processing Record 25 of Set 6 | mkushi
# Processing Record 26 of Set 6 | yakeshi
# Processing Record 27 of Set 6 | neuquen
# Processing Record 28 of Set 6 | korla
# Processing Record 29 of Set 6 | tecoanapa
# Processing Record 30 of Set 6 | liverpool
# Processing Record 31 of Set 6 | palabuhanratu
# City not found. Skipping...palabuhanratu
# Processing Record 32 of Set 6 | bonthe
# Processing Record 33 of Set 6 | auki
# Processing Record 34 of Set 6 | arboletes
# Processing Record 35 of Set 6 | bambous virieux
# Processing Record 36 of Set 6 | bani walid
# Processing Record 37 of Set 6 | siocon
# Processing Record 38 of Set 6 | daru
# Processing Record 39 of Set 6 | el naranjo
# Processing Record 40 of Set 6 | college place
# Processing Record 41 of Set 6 | tianpeng
# Processing Record 42 of Set 6 | bairnsdale
# Processing Record 43 of Set 6 | matay
# Processing Record 44 of Set 6 | meadow lake
# Processing Record 45 of Set 6 | dubovskoye
# Processing Record 46 of Set 6 | kapit
# Processing Record 47 of Set 6 | beringovskiy
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | waingapu
# Processing Record 50 of Set 6 | spas-demensk
# Processing Record 1 of Set 7 | aflu
# City not found. Skipping...aflu
# Processing Record 2 of Set 7 | disraeli
# Processing Record 3 of Set 7 | mys shmidta
# City not found. Skipping...mys shmidta
# Processing Record 4 of Set 7 | snasa
# Processing Record 5 of Set 7 | narasapur
# Processing Record 6 of Set 7 | basco
# Processing Record 7 of Set 7 | krasnoselkup
# Processing Record 8 of Set 7 | chapada dos guimaraes
# Processing Record 9 of Set 7 | keningau
# Processing Record 10 of Set 7 | toliary
# City not found. Skipping...toliary
# Processing Record 11 of Set 7 | port macquarie
# Processing Record 12 of Set 7 | barcelona
# Processing Record 13 of Set 7 | bonao
# Processing Record 14 of Set 7 | tabou
# Processing Record 15 of Set 7 | quelimane
# Processing Record 16 of Set 7 | jaque
# Processing Record 17 of Set 7 | valdivia
# Processing Record 18 of Set 7 | obo
# Processing Record 19 of Set 7 | zaykovo
# Processing Record 20 of Set 7 | lompoc
# Processing Record 21 of Set 7 | urumqi
# Processing Record 22 of Set 7 | yulara
# Processing Record 23 of Set 7 | ganzhou
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | maan
# Processing Record 26 of Set 7 | victoria
# Processing Record 27 of Set 7 | baruun-urt
# Processing Record 28 of Set 7 | port blair
# Processing Record 29 of Set 7 | outlook
# Processing Record 30 of Set 7 | nelson bay
# Processing Record 31 of Set 7 | barentsburg
# City not found. Skipping...barentsburg
# Processing Record 32 of Set 7 | gouloure
# Processing Record 33 of Set 7 | kidal
# Processing Record 34 of Set 7 | aden
# Processing Record 35 of Set 7 | ngukurr
# City not found. Skipping...ngukurr
# Processing Record 36 of Set 7 | serenje
# Processing Record 37 of Set 7 | kalabo
# Processing Record 38 of Set 7 | lazarev
# Processing Record 39 of Set 7 | dauphin
# Processing Record 40 of Set 7 | saint-georges
# Processing Record 41 of Set 7 | lerwick
# Processing Record 42 of Set 7 | union
# Processing Record 43 of Set 7 | kodinsk
# Processing Record 44 of Set 7 | ojinaga
# Processing Record 45 of Set 7 | zhangjiakou
# Processing Record 46 of Set 7 | alice town
# Processing Record 47 of Set 7 | stephenville
# Processing Record 48 of Set 7 | fukue
# Processing Record 49 of Set 7 | olafsvik
# Processing Record 50 of Set 7 | riihimaki
# Processing Record 1 of Set 8 | kumta
# Processing Record 2 of Set 8 | andreapol
# Processing Record 3 of Set 8 | liberal
# Processing Record 4 of Set 8 | lac du bonnet
# Processing Record 5 of Set 8 | port moresby
# Processing Record 6 of Set 8 | ornskoldsvik
# Processing Record 7 of Set 8 | axim
# Processing Record 8 of Set 8 | erdenet
# Processing Record 9 of Set 8 | narsaq
# Processing Record 10 of Set 8 | guilin
# Processing Record 11 of Set 8 | labuhan
# Processing Record 12 of Set 8 | matagami
# Processing Record 13 of Set 8 | ormara
# Processing Record 14 of Set 8 | olinda
# Processing Record 15 of Set 8 | jumla
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | rognan
# Processing Record 18 of Set 8 | lieksa
# Processing Record 19 of Set 8 | kavieng
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | quang ngai
# Processing Record 22 of Set 8 | sitka
# Processing Record 23 of Set 8 | kuching
# Processing Record 24 of Set 8 | saleaula
# City not found. Skipping...saleaula
# Processing Record 25 of Set 8 | pando
# Processing Record 26 of Set 8 | kuruman
# Processing Record 27 of Set 8 | jahrom
# City not found. Skipping...jahrom
# Processing Record 28 of Set 8 | natal
# Processing Record 29 of Set 8 | arrecife
# Processing Record 30 of Set 8 | hay river
# Processing Record 31 of Set 8 | sinnamary
# Processing Record 32 of Set 8 | kenai
# Processing Record 33 of Set 8 | thunder bay
# Processing Record 34 of Set 8 | santa maria
# Processing Record 35 of Set 8 | henties bay
# Processing Record 36 of Set 8 | humaita
# Processing Record 37 of Set 8 | mendahara
# City not found. Skipping...mendahara
# Processing Record 38 of Set 8 | visby
# Processing Record 39 of Set 8 | maceio
# Processing Record 40 of Set 8 | san carlos de bariloche
# Processing Record 41 of Set 8 | yeppoon
# Processing Record 42 of Set 8 | oktyabrskoye
# Processing Record 43 of Set 8 | buala
# Processing Record 44 of Set 8 | grindavik
# Processing Record 45 of Set 8 | iqaluit
# Processing Record 46 of Set 8 | sur
# Processing Record 47 of Set 8 | champerico
# Processing Record 48 of Set 8 | perbaungan
# Processing Record 49 of Set 8 | taburi
# City not found. Skipping...taburi
# Processing Record 50 of Set 8 | eirunepe
# Processing Record 1 of Set 9 | bengkulu
# Processing Record 2 of Set 9 | methoni
# Processing Record 3 of Set 9 | torbay
# Processing Record 4 of Set 9 | marsa matruh
# Processing Record 5 of Set 9 | hualmay
# Processing Record 6 of Set 9 | saint-augustin
# Processing Record 7 of Set 9 | camana
# Processing Record 8 of Set 9 | cap malheureux
# Processing Record 9 of Set 9 | cacu
# Processing Record 10 of Set 9 | college
# Processing Record 11 of Set 9 | pacific grove
# Processing Record 12 of Set 9 | amapa
# Processing Record 13 of Set 9 | warri
# Processing Record 14 of Set 9 | coahuayana
# Processing Record 15 of Set 9 | zyryanka
# Processing Record 16 of Set 9 | lavrentiya
# Processing Record 17 of Set 9 | fayaoue
# Processing Record 18 of Set 9 | estelle
# Processing Record 19 of Set 9 | acarau
# Processing Record 20 of Set 9 | zhigansk
# Processing Record 21 of Set 9 | evensk
# Processing Record 22 of Set 9 | arvika
# Processing Record 23 of Set 9 | mogadishu
# Processing Record 24 of Set 9 | bac lieu
# Processing Record 25 of Set 9 | areosa
# Processing Record 26 of Set 9 | mount isa
# Processing Record 27 of Set 9 | crotone
# Processing Record 28 of Set 9 | marsh harbour
# Processing Record 29 of Set 9 | louga
# Processing Record 30 of Set 9 | awjilah
# Processing Record 31 of Set 9 | dudinka
# Processing Record 32 of Set 9 | vestmannaeyjar
# Processing Record 33 of Set 9 | victoria point
# Processing Record 34 of Set 9 | severodvinsk
# Processing Record 35 of Set 9 | iberia
# Processing Record 36 of Set 9 | shchebetovka
# Processing Record 37 of Set 9 | tabira
# Processing Record 38 of Set 9 | filimonovo
# Processing Record 39 of Set 9 | richards bay
# Processing Record 40 of Set 9 | ribas do rio pardo
# Processing Record 41 of Set 9 | chokurdakh
# Processing Record 42 of Set 9 | tiznit
# Processing Record 43 of Set 9 | imbituba
# Processing Record 44 of Set 9 | chulman
# Processing Record 45 of Set 9 | muros
# Processing Record 46 of Set 9 | iquitos
# Processing Record 47 of Set 9 | chernyshevskiy
# Processing Record 48 of Set 9 | boende
# Processing Record 49 of Set 9 | tahoua
# Processing Record 50 of Set 9 | doctor pedro p. pena
# City not found. Skipping...doctor pedro p. pena
# Processing Record 1 of Set 10 | kalmunai
# Processing Record 2 of Set 10 | anaconda
# Processing Record 3 of Set 10 | saint-pierre
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | miami
# Processing Record 6 of Set 10 | lac-megantic
# Processing Record 7 of Set 10 | zunyi
# Processing Record 8 of Set 10 | namie
# Processing Record 9 of Set 10 | jibuti
# Processing Record 10 of Set 10 | karauzyak
# City not found. Skipping...karauzyak
# Processing Record 11 of Set 10 | vao
# Processing Record 12 of Set 10 | boyuibe
# Processing Record 13 of Set 10 | fare
# Processing Record 14 of Set 10 | luancheng
# Processing Record 15 of Set 10 | barkot
# Processing Record 16 of Set 10 | mareeba
# Processing Record 17 of Set 10 | ambon
# Processing Record 18 of Set 10 | bayir
# Processing Record 19 of Set 10 | sekoma
# Processing Record 20 of Set 10 | louisbourg
# City not found. Skipping...louisbourg
# Processing Record 21 of Set 10 | abalak
# Processing Record 22 of Set 10 | vanimo
# Processing Record 23 of Set 10 | port hardy
# Processing Record 24 of Set 10 | udachnyy
# Processing Record 25 of Set 10 | general roca
# Processing Record 26 of Set 10 | thinadhoo
# Processing Record 27 of Set 10 | labranzagrande
# Processing Record 28 of Set 10 | kasangulu
# Processing Record 29 of Set 10 | zelenogorskiy
# Processing Record 30 of Set 10 | mahon
# Processing Record 31 of Set 10 | klaksvik
# Processing Record 32 of Set 10 | tabas
# Processing Record 33 of Set 10 | kaffrine
# Processing Record 34 of Set 10 | novo aripuana
# Processing Record 35 of Set 10 | ayios kirikos
# City not found. Skipping...ayios kirikos
# Processing Record 36 of Set 10 | katangli
# Processing Record 37 of Set 10 | talara
# Processing Record 38 of Set 10 | carutapera
# Processing Record 39 of Set 10 | la ronge
# Processing Record 40 of Set 10 | rio rancho
# Processing Record 41 of Set 10 | kitimat
# Processing Record 42 of Set 10 | plaster rock
# Processing Record 43 of Set 10 | pekan
# Processing Record 44 of Set 10 | hobyo
# Processing Record 45 of Set 10 | egvekinot
# Processing Record 46 of Set 10 | pampierstad
# Processing Record 47 of Set 10 | tuatapere
# Processing Record 48 of Set 10 | mandalgovi
# Processing Record 49 of Set 10 | guna
# Processing Record 50 of Set 10 | caravelas
# Processing Record 1 of Set 11 | shimoda
# Processing Record 2 of Set 11 | sisimiut
# Processing Record 3 of Set 11 | belmonte
# Processing Record 4 of Set 11 | laguna
# Processing Record 5 of Set 11 | oranjemund
# Processing Record 6 of Set 11 | portland
# Processing Record 7 of Set 11 | paita
# Processing Record 8 of Set 11 | dingle
# Processing Record 9 of Set 11 | presidencia roque saenz pena
# Processing Record 10 of Set 11 | praia da vitoria
# Processing Record 11 of Set 11 | sistranda
# Processing Record 12 of Set 11 | lorengau
# Processing Record 13 of Set 11 | fevralsk
# City not found. Skipping...fevralsk
# Processing Record 14 of Set 11 | celestun
# Processing Record 15 of Set 11 | ust-kut
# Processing Record 16 of Set 11 | thayetmyo
# Processing Record 17 of Set 11 | sataua
# City not found. Skipping...sataua
# Processing Record 18 of Set 11 | shchelyayur
# City not found. Skipping...shchelyayur
# Processing Record 19 of Set 11 | bibiani
# Processing Record 20 of Set 11 | salym
# Processing Record 21 of Set 11 | chagda
# City not found. Skipping...chagda
# Processing Record 22 of Set 11 | sangar
# Processing Record 23 of Set 11 | quatre cocos
# Processing Record 24 of Set 11 | laurel
# Processing Record 25 of Set 11 | cockburn town
# Processing Record 26 of Set 11 | marzuq
# Processing Record 27 of Set 11 | road town
# Processing Record 28 of Set 11 | bako
# Processing Record 29 of Set 11 | tarudant
# City not found. Skipping...tarudant
# Processing Record 30 of Set 11 | vostok
# Processing Record 31 of Set 11 | shirokiy
# Processing Record 32 of Set 11 | khormuj
# City not found. Skipping...khormuj
# Processing Record 33 of Set 11 | shenandoah
# Processing Record 34 of Set 11 | husavik
# Processing Record 35 of Set 11 | bilma
# Processing Record 36 of Set 11 | escarcega
# Processing Record 37 of Set 11 | aruppukkottai
# Processing Record 38 of Set 11 | mahbubabad
# Processing Record 39 of Set 11 | porto novo
# Processing Record 40 of Set 11 | bubaque
# Processing Record 41 of Set 11 | kintampo
# Processing Record 42 of Set 11 | clinton
# Processing Record 43 of Set 11 | platteville
# Processing Record 44 of Set 11 | bolungarvik
# City not found. Skipping...bolungarvik
# Processing Record 45 of Set 11 | bandrele
# Processing Record 46 of Set 11 | cervo
# Processing Record 47 of Set 11 | san antonio
# Processing Record 48 of Set 11 | svetlogorsk
# Processing Record 49 of Set 11 | springdale
# Processing Record 50 of Set 11 | brae
# Processing Record 1 of Set 12 | okha
# Processing Record 2 of Set 12 | andenes
# Processing Record 3 of Set 12 | salinopolis
# Processing Record 4 of Set 12 | seoul
# Processing Record 5 of Set 12 | eyl
# Processing Record 6 of Set 12 | pascagoula
# Processing Record 7 of Set 12 | de aar
# Processing Record 8 of Set 12 | maniitsoq
# Processing Record 9 of Set 12 | nhulunbuy
# Processing Record 10 of Set 12 | komsomolskiy
# Processing Record 11 of Set 12 | novyy urengoy
# Processing Record 12 of Set 12 | umm lajj
# Processing Record 13 of Set 12 | bajil
# Processing Record 14 of Set 12 | proletariy
# Processing Record 15 of Set 12 | dagana
# Processing Record 16 of Set 12 | peniche
# Processing Record 17 of Set 12 | nizhniy kuranakh
# Processing Record 18 of Set 12 | belaya gora
# Processing Record 19 of Set 12 | fayetteville
# Processing Record 20 of Set 12 | kharan
# Processing Record 21 of Set 12 | nome
# Processing Record 22 of Set 12 | diffa
# Processing Record 23 of Set 12 | linxia
# Processing Record 24 of Set 12 | cabedelo
# Processing Record 25 of Set 12 | jedrzejow
# Processing Record 26 of Set 12 | sabya
# Processing Record 27 of Set 12 | antropovo
# Processing Record 28 of Set 12 | funehiki
# Processing Record 29 of Set 12 | burnie
# Processing Record 30 of Set 12 | solnechnyy
# Processing Record 31 of Set 12 | luganville
# Processing Record 32 of Set 12 | aquiraz
# Processing Record 33 of Set 12 | maldonado
# Processing Record 34 of Set 12 | san rafael
# Processing Record 35 of Set 12 | gimli
# Processing Record 36 of Set 12 | bathsheba
# Processing Record 37 of Set 12 | bogande
# Processing Record 38 of Set 12 | cangzhou
# Processing Record 39 of Set 12 | buin
# Processing Record 40 of Set 12 | pyapon
# Processing Record 41 of Set 12 | amberieu-en-bugey
# Processing Record 42 of Set 12 | topchikha
# Processing Record 43 of Set 12 | kangasala
# Processing Record 44 of Set 12 | jimo
# Processing Record 45 of Set 12 | langsa
# Processing Record 46 of Set 12 | havelock
# Processing Record 47 of Set 12 | porto walter
# Processing Record 48 of Set 12 | pasighat
# Processing Record 49 of Set 12 | tongchuan
# Processing Record 50 of Set 12 | dom pedrito
# Processing Record 1 of Set 13 | plastun
# Processing Record 2 of Set 13 | rungata
# City not found. Skipping...rungata
# Processing Record 3 of Set 13 | linshu
# City not found. Skipping...linshu
# Processing Record 4 of Set 13 | ha giang
# Processing Record 5 of Set 13 | tautira
# Processing Record 6 of Set 13 | kazalinsk
# City not found. Skipping...kazalinsk
# Processing Record 7 of Set 13 | biak
# Processing Record 8 of Set 13 | teya
# Processing Record 9 of Set 13 | gusau
# Processing Record 10 of Set 13 | mountain home
# Processing Record 11 of Set 13 | dunedin
# Processing Record 12 of Set 13 | palana
# Processing Record 13 of Set 13 | itoman
# Processing Record 14 of Set 13 | puerto leguizamo
# Processing Record 15 of Set 13 | shrigonda
# Processing Record 16 of Set 13 | wanning
# Processing Record 17 of Set 13 | wattegama
# Processing Record 18 of Set 13 | pangody
# Processing Record 19 of Set 13 | joshimath
# Processing Record 20 of Set 13 | balky
# Processing Record 21 of Set 13 | halalo
# City not found. Skipping...halalo
# Processing Record 22 of Set 13 | buraydah
# Processing Record 23 of Set 13 | gulu
# Processing Record 24 of Set 13 | yaan
# Processing Record 25 of Set 13 | harper
# Processing Record 26 of Set 13 | san juan
# Processing Record 27 of Set 13 | wulanhaote
# City not found. Skipping...wulanhaote
# Processing Record 28 of Set 13 | cap-aux-meules
# Processing Record 29 of Set 13 | cordoba
# Processing Record 30 of Set 13 | itambe
# Processing Record 31 of Set 13 | ayni
# Processing Record 32 of Set 13 | acari
# Processing Record 33 of Set 13 | atar
# Processing Record 34 of Set 13 | opunake
# Processing Record 35 of Set 13 | yoichi
# Processing Record 36 of Set 13 | mnogovershinnyy
# Processing Record 37 of Set 13 | luoyang
# Processing Record 38 of Set 13 | kathu
# Processing Record 39 of Set 13 | pringsewu
# Processing Record 40 of Set 13 | mayskiy
# Processing Record 41 of Set 13 | jalu
# Processing Record 42 of Set 13 | morgan city
# Processing Record 43 of Set 13 | geraldton
# Processing Record 44 of Set 13 | los llanos de aridane
# Processing Record 45 of Set 13 | radviliskis
# Processing Record 46 of Set 13 | port-de-paix
# City not found. Skipping...port-de-paix
# Processing Record 47 of Set 13 | garissa
# Processing Record 48 of Set 13 | ulaangom
# Processing Record 49 of Set 13 | pergamino
# Processing Record 50 of Set 13 | avera
# Processing Record 1 of Set 14 | chapais
# Processing Record 2 of Set 14 | hambantota
# Processing Record 3 of Set 14 | gizo
# Processing Record 4 of Set 14 | garowe
# Processing Record 5 of Set 14 | bontang
# Processing Record 6 of Set 14 | zamora
# Processing Record 7 of Set 14 | homer
# Processing Record 8 of Set 14 | tabuk
# Processing Record 9 of Set 14 | inverness
# Processing Record 10 of Set 14 | pochinok
# Processing Record 11 of Set 14 | lano
# Processing Record 12 of Set 14 | colares
# Processing Record 13 of Set 14 | saltpond
# Processing Record 14 of Set 14 | saldanha
# Processing Record 15 of Set 14 | esil
# Processing Record 16 of Set 14 | mutsamudu
# City not found. Skipping...mutsamudu
# Processing Record 17 of Set 14 | linqiong
# Processing Record 18 of Set 14 | sao jose da coroa grande
# Processing Record 19 of Set 14 | ostrovnoy
# Processing Record 20 of Set 14 | bodden town
# Processing Record 21 of Set 14 | chara
# Processing Record 22 of Set 14 | berlevag
# Processing Record 23 of Set 14 | rock sound
# Processing Record 24 of Set 14 | mezen
# Processing Record 25 of Set 14 | svetlaya
# Processing Record 26 of Set 14 | sirkali
# City not found. Skipping...sirkali
# Processing Record 27 of Set 14 | bassila
# Processing Record 28 of Set 14 | makat
# Processing Record 29 of Set 14 | lazy
# Processing Record 30 of Set 14 | dongsheng
# Processing Record 31 of Set 14 | ngudu
# Processing Record 32 of Set 14 | lethem
# Processing Record 33 of Set 14 | sao tome
# Processing Record 34 of Set 14 | nouadhibou
# Processing Record 35 of Set 14 | ergani
# Processing Record 36 of Set 14 | raudeberg
# Processing Record 37 of Set 14 | falkoping
# City not found. Skipping...falkoping
# Processing Record 38 of Set 14 | vigrestad
# Processing Record 39 of Set 14 | kula
# Processing Record 40 of Set 14 | kamenka
# Processing Record 41 of Set 14 | nam som
# Processing Record 42 of Set 14 | el tigre
# Processing Record 43 of Set 14 | dalvik
# Processing Record 44 of Set 14 | inirida
# Processing Record 45 of Set 14 | mocambique
# City not found. Skipping...mocambique
# Processing Record 46 of Set 14 | kloulklubed
# Processing Record 47 of Set 14 | leningradskiy
# Processing Record 48 of Set 14 | ballina
# Processing Record 49 of Set 14 | burkhala
# City not found. Skipping...burkhala
# Processing Record 50 of Set 14 | mogocha
# Processing Record 1 of Set 15 | palamos
# Processing Record 2 of Set 15 | ulladulla
# Processing Record 3 of Set 15 | hinton
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | chaa-khol
# City not found. Skipping...chaa-khol
# Processing Record 6 of Set 15 | asfi
# Processing Record 7 of Set 15 | mahibadhoo
# Processing Record 8 of Set 15 | idrinskoye
# Processing Record 9 of Set 15 | rolim de moura
# City not found. Skipping...rolim de moura
# Processing Record 10 of Set 15 | buk
# Processing Record 11 of Set 15 | batagay-alyta
# Processing Record 12 of Set 15 | taree
# Processing Record 13 of Set 15 | gornopravdinsk
# Processing Record 14 of Set 15 | shubarkuduk
# Processing Record 15 of Set 15 | mormugao
# Processing Record 16 of Set 15 | diamantino
# Processing Record 17 of Set 15 | grants pass
# Processing Record 18 of Set 15 | longhua
# Processing Record 19 of Set 15 | cotacachi
# Processing Record 20 of Set 15 | andover
# Processing Record 21 of Set 15 | xining
# Processing Record 22 of Set 15 | moron
# Processing Record 23 of Set 15 | tucuman
# Processing Record 24 of Set 15 | tromso
# Processing Record 25 of Set 15 | myitkyina
# Processing Record 26 of Set 15 | santa marta
# Processing Record 27 of Set 15 | rumoi
# Processing Record 28 of Set 15 | marsciano
# Processing Record 29 of Set 15 | ahipara
# Processing Record 30 of Set 15 | matara
# Processing Record 31 of Set 15 | przasnysz
# Processing Record 32 of Set 15 | krasnoyarsk-66
# City not found. Skipping...krasnoyarsk-66
# Processing Record 33 of Set 15 | puerto colombia
# Processing Record 34 of Set 15 | barcelos
# Processing Record 35 of Set 15 | eureka
# Processing Record 36 of Set 15 | paracuru
# Processing Record 37 of Set 15 | penzance
# Processing Record 38 of Set 15 | rafai
# Processing Record 39 of Set 15 | miraflores
# Processing Record 40 of Set 15 | bosobolo
# Processing Record 41 of Set 15 | richfield
# Processing Record 42 of Set 15 | tessalit
# Processing Record 43 of Set 15 | coihueco
# Processing Record 44 of Set 15 | le port
# Processing Record 45 of Set 15 | acapulco
# Processing Record 46 of Set 15 | mbanza-ngungu
# Processing Record 47 of Set 15 | shelburne
# Processing Record 48 of Set 15 | araouane
# Processing Record 49 of Set 15 | batsfjord
# Processing Record 50 of Set 15 | kismayo
# Processing Record 1 of Set 16 | ruatoria
# City not found. Skipping...ruatoria
# Processing Record 2 of Set 16 | sawakin
# Processing Record 3 of Set 16 | assiniboia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0       Qaanaaq  77.4840  -69.3632     overcast clouds    -17.50        93
# 1      Takoradi   4.8845   -1.7554    scattered clouds     83.88        73
# 2  Kruisfontein -34.0033   24.7314          light rain     83.73        53
# 3       Ushuaia -54.8000  -68.3000       broken clouds     46.02        70
# 4      Yuncheng  35.0231  110.9928           clear sky     39.45        66
# 5       Rikitea -23.1203 -134.9692          light rain     76.50        69
# 6      Tasiilaq  65.6145  -37.6368                snow     24.66        89
# 7        Tiarei -17.5333 -149.3333       broken clouds     77.02        74
# 8         Bluff -46.6000  168.3333     overcast clouds     58.80        94
# 9      Tarazona  41.9000   -1.7333       broken clouds     55.99        37
#
#    Cloudiness  Wind Speed Country                 Date
# 0          99        5.97      GL  2022-02-15 14:50:10
# 1          43        9.55      GH  2022-02-15 14:50:11
# 2          91       12.44      ZA  2022-02-15 14:50:13
# 3          75       23.02      AR  2022-02-15 14:50:14
# 4           6        6.35      CN  2022-02-15 14:50:15
# 5          42        2.10      PF  2022-02-15 14:50:16
# 6         100       37.63      GL  2022-02-15 14:50:17
# 7          70       12.68      PF  2022-02-15 14:50:18
# 8         100       11.81      NZ  2022-02-15 14:50:19
# 9          72       10.29      ES  2022-02-15 14:50:20

# %%
new_column_order_df = city_data_df.reindex(columns= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"])
new_column_order_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq      GL  77.4840  -69.3632    -17.50        93          99
# 1      Takoradi      GH   4.8845   -1.7554     83.88        73          43
# 2  Kruisfontein      ZA -34.0033   24.7314     83.73        53          91
# 3       Ushuaia      AR -54.8000  -68.3000     46.02        70          75
# 4      Yuncheng      CN  35.0231  110.9928     39.45        66           6
# 5       Rikitea      PF -23.1203 -134.9692     76.50        69          42
# 6      Tasiilaq      GL  65.6145  -37.6368     24.66        89         100
# 7        Tiarei      PF -17.5333 -149.3333     77.02        74          70
# 8         Bluff      NZ -46.6000  168.3333     58.80        94         100
# 9      Tarazona      ES  41.9000   -1.7333     55.99        37          72
#
#    Wind Speed Current Description
# 0        5.97     overcast clouds
# 1        9.55    scattered clouds
# 2       12.44          light rain
# 3       23.02       broken clouds
# 4        6.35           clear sky
# 5        2.10          light rain
# 6       37.63                snow
# 7       12.68       broken clouds
# 8       11.81     overcast clouds
# 9       10.29       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_column_order_df.to_csv(output_data_file, index_label="City_ID")
